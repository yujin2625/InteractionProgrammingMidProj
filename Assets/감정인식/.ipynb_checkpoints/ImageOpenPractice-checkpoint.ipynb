# %%
from PIL import Image

Image.open('D:/Desktop/백업/바탕화면/사진/증명사진/KakaoTalk_20220515_030200987_01.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=413x531>

# %%
import cv2
import numpy as np

img = cv2.imread('./sample/sample1.jpg',cv2.IMREAD_COLOR)

print(type(img))
print(img.shape)

pil_Image = Image.fromarray(img)

cv2.imshow('image',img)
# Out:
# <class 'numpy.ndarray'>
# (531, 413, 3)

# %%
import matplotlib.pyplot as plt

# cv2 Image (=Numpy Image)
cv2_img = cv2.imread("./sample/sample1.jpg")

plt.imshow(cv2_img)
